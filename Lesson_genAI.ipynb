# %% [markdown]
# <a href="https://colab.research.google.com/github/sduttawork1987/Machine-learning-prep/blob/main/Lesson_genAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=100

# %%
#Declaring and assigning variables
age=39
height=5.7
name="Subham Dutta"
is_student=True

print("age:", age)
print("height:", height)
print("name:", name)
print("is_student:", is_student)
# Out:
# age: 39
# height: 5.7
# name: Subham Dutta
# is_student: True
